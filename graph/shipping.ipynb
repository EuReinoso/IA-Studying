# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/shipping.csv')

df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
corrn = df.corr()
plt.figure(figsize= (10, 8))
sns.heatmap(corrn, annot= True, vmax= 0.8)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['Gender'])
print(df['Gender'].value_counts())
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Cost_of_the_Product'].describe()
# Out:
# count    10999.000000
# mean       210.196836
# std         48.063272
# min         96.000000
# 25%        169.000000
# 50%        214.000000
# 75%        251.000000
# max        310.000000
# Name: Cost_of_the_Product, dtype: float64

# %%
plt.figure(figsize= (10, 5))
sns.histplot(df['Cost_of_the_Product'])
# Out:
# <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Count'>

# %%
plt.figure(figsize= (10, 5))
sns.boxplot(df['Cost_of_the_Product'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cost_of_the_Product'>

# %%
df['Customer_rating'].describe()
# Out:
# count    10999.000000
# mean         2.990545
# std          1.413603
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Customer_rating, dtype: float64

# %%
sns.histplot(df['Customer_rating'])
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Count'>

# %%
df['Customer_care_calls'].describe()
# Out:
# count    10999.000000
# mean         4.054459
# std          1.141490
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          7.000000
# Name: Customer_care_calls, dtype: float64

# %%
sns.countplot(df['Customer_care_calls'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer_care_calls', ylabel='count'>

# %%
df['Product_importance'].value_counts()
# Out:
# low       5297
# medium    4754
# high       948
# Name: Product_importance, dtype: int64

# %%
sns.countplot(df['Product_importance'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_importance', ylabel='count'>

# %%
df['Mode_of_Shipment'].value_counts()
# Out:
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64

# %%
sns.countplot(df['Mode_of_Shipment'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='count'>

# %%
df['Discount_offered'].describe()
# Out:
# count    10999.000000
# mean        13.373216
# std         16.205527
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         65.000000
# Name: Discount_offered, dtype: float64

# %%
sns.histplot(df['Discount_offered'])
# Out:
# <AxesSubplot:xlabel='Discount_offered', ylabel='Count'>

# %%
sns.boxplot(df['Discount_offered'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount_offered'>

# %%
df['Reached.on.Time_Y.N'].value_counts()
df['is_on_time'] = df['Reached.on.Time_Y.N'].map({0 : 'On time', 1 : 'Not on time'})

df['is_on_time'].value_counts()
# Out:
# Not on time    6563
# On time        4436
# Name: is_on_time, dtype: int64

# %%
sns.countplot(df['is_on_time'])
# Out:
# /home/reinoso/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='is_on_time', ylabel='count'>

# %%
sns.boxplot(x= 'Customer_rating',y= 'Cost_of_the_Product', data= df)
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Cost_of_the_Product'>

# %%
sns.boxplot(x= 'Gender', y= 'Cost_of_the_Product', data= df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Cost_of_the_Product'>

# %%
sns.boxplot(x= 'Gender', y= 'Discount_offered', data= df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Discount_offered'>

# %%
sns.boxplot(x= 'Product_importance', y= 'Discount_offered', data= df)
# Out:
# <AxesSubplot:xlabel='Product_importance', ylabel='Discount_offered'>

# %%
sns.scatterplot(x= 'Cost_of_the_Product', y= 'Discount_offered', data= df)
# Out:
# <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Discount_offered'>

# %%
sns.boxplot(x= 'Cost_of_the_Product', y= 'Product_importance', data= df)
# Out:
# <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Product_importance'>
